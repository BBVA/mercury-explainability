# %% [markdown]
# # Tutorial mercury-explainability
#
# ## Setup
#
# We use mercury.explainabilty and mercury.data in this tutorial. In Datio, you can install them executing the next command in a cell:
# ```sh
# pip install --user mercury-explainability<0.3
# ```
#
# If you are in ADA:
# ```sh
# pip install mercury-explainability>=0.3
# ```
#
# If you are in local or Colab, you can install them by first setting the ARTIFACTORY_BOT_BASIC_AUTH variable:
# ```
# ARTIFACTORY_USER_PROFILE = "YOUR_USER_ID"
# ARTIFACTORY_API_KEY = "YOUR_ARTIFACTORY_KEY"
# ARTIFACTORY_BOT_BASIC_AUTH = f"{ARTIFACTORY_USER_PROFILE}:{ARTIFACTORY_API_KEY}"
# ```
#
# and then executing the pip install specifying BBVA Artifactory with the extra-index option:
# ```sh
# pip install mercury-explainability -U  --extra-index-url https://{ARTIFACTORY_BOT_BASIC_AUTH}@artifactory.globaldevtools.bbva.com/artifactory/api/pypi/gl-datio-runtime-pypi-virtual/simple --extra-index-url https://\${ARTIFACTORY_BOT_BASIC_AUTH}@artifactory.globaldevtools.bbva.com/artifactory/api/pypi/gl-datio-aifactory-pypi-local/simple
# ```
# ---
# Este notebook muestra, a modo de prueba, el uso de mercury-explainability para obtener interpretaciones de dos modelos: uno basado en sklearn y otro en PySpark; por medio de varios explainers.
#
# En este ejemplo utilizaremos el dataset **Iris de sklearn**, sobre el que entrenaremos dos RF, uno de sklearn y otro de spark.

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn import ensemble
# %matplotlib inline

from pyspark.sql import SparkSession
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.feature import VectorAssembler

# %%
# Instanciamos el dataset
iris = datasets.load_iris()

predictors = pd.DataFrame(iris.data, columns=iris.feature_names)
target = iris.target

full_df = pd.DataFrame(iris.data, columns=iris.feature_names)
full_df['label'] = target

# %% [markdown]
# Entrenamos el modelo de **sklearn**

# %%
rf = ensemble.RandomForestClassifier(n_estimators=500)
rf = rf.fit(iris.data, iris.target)

# %% [markdown]
# Entrenamos el modelo de **PySpark**

# %%
spark = SparkSession.builder.appName("Mercury Example").getOrCreate()

spark_dataset = spark.createDataFrame(full_df)
vectAssembler = VectorAssembler(inputCols=iris.feature_names, outputCol="features")
spark_dataset = vectAssembler.transform(spark_dataset)

rf_predictor = RandomForestClassifier(labelCol="label", featuresCol="features", numTrees=10)
model = rf_predictor.fit(spark_dataset)

# %% [markdown]
# ## CounterFactualBasic
#
# Vamos a probar el primer explainer: **CounterFactualBasic** (el anteriormente llamado PanelletExplainer).

# %%
from mercury.explainability import CounterFactualExplainerBasic

# %%
counterfactual_basic = CounterFactualExplainerBasic(
    predictors,
    rf.predict_proba  # Model prediction function which returns class distribution probabilities
)

# %% [markdown]
# El parametro basico en .explain es la/las instancias de los datos a explicar. A partir de ahí, cada tipo de explainer tiene parámetros propios que se pueden tunear en función de los datos y el modelo de manera que se pueda converger antes.

# %%
explanation = counterfactual_basic.explain(predictors.head(1).values.flatten(), 
                                           threshold=.9, 
                                           class_idx=2,
                                           step=np.array([.1] * 4))

# %%
explanation.show(figsize=(5, 3))
# Out:
# Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations

# %% [markdown]
# También podemos hacer lo mismo con el modelo de Spark, aunque es necesario "envolverlo" en una clase propia que se encarga de hacer la traducción entre numpy/pandas y Spark. Para ello usamos un **SparkWrapper**

# %%
from mercury.explainability.pyspark_utils import SparkWrapper

# %%
model_w = SparkWrapper(
    model,
    iris.feature_names,
    spark_session=spark,
    # Si cambiamos las entradas/salidas del modelo, tendremos que especificarlo
    model_inp_name="features",
    model_out_name="probability",
)

# %% [markdown]
# Para usarlo, simplemente tenemos que pasar nuestro modelo envuelto en vez de una lambda/rf.predict_proba
#
# <div class="alert alert-warning">
#     Nota: La comunicación entre Pyspark y la JVM es costosa. Debido a esto, las explicaciones de modelos de Spark serán más lentas.
# </div>

# %%
counterfactual_basic = CounterFactualExplainerBasic(
    predictors,
    model_w
)

explanation = counterfactual_basic.explain(predictors.head(1).values.flatten(), 
                                           threshold=.9, 
                                           class_idx=2, 
                                           step=np.array([.1] * 4))
explanation.show(figsize=(5, 3))
# Out:
# Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations

# %% [markdown]
# **(Con propósito de ejecutar el notebook rápidamente y no hacerlo muy extenso, no se añadirán más ejemplos de Spark pues el funcionamiento es similar al anterior)**
#
#
# ## CounterFactualProto
# A continuación, usamos un explainer supervisado: Counter Factual guiado por prototipos.
#
# Este modelo extiende al implementado en Alibi. Es recomentable leer su documentación ya que comparten varios parámetros.
#
# https://docs.seldon.io/projects/alibi/en/stable/methods/CF.html?highlight=explanation#Counterfactual-Instances

# %% [markdown]
# <div class="alert alert-warning">
#     Nota: Para que funcione el <b>CounterfactualProtoExplainer</b> con las versiones más modernas de Tensorflow es posible que sea necesario deshabilitar la eager execution. Puede deshabilitarla ejecutando:
# </div>
#
# ```python
# import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
# ```

# %%
from mercury.explainability import CounterfactualProtoExplainer
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# Set max_iterations to 200

# %%
cfExplainer = CounterfactualProtoExplainer(
    predict_fn=rf.predict_proba,
    train_data=predictors,  # tambien puede ser un np.array, pero si pasamos un pd.DataFrame el explainer 
                            # inferira varios parametros
    # Estos parametros no son necesarios pero haran al explainer acabar antes
    theta=10, 
    max_iterations=20, 
    eps=(5e-2, 5e-2), 
    feature_range=(-10,10),
    #c_init=c_init, 
    #c_steps=c_steps,
)
# Out:
# WARNING:alibi.explainers.cfproto:No encoder specified. Using k-d trees to represent class prototypes.

# %%
# Esto va a llevar un rato...
# La explicacion retornada es un diccionario con todos los datos.
# ver: https://docs.seldon.io/projects/alibi/en/stable/methods/CF.html?highlight=explanation#Explanation
cf_explanation = cfExplainer.explain(predictors.head(1).values)

# %% [markdown]
# La particularidad de estos CounterFactual explainers es que añaden un metodo que permite obtener la importancia de las features para el modelo

# %%
# %time
cfExplainer.get_feature_importance(predictors.head(5))
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 10.3 µs
# WARNING:alibi.explainers.cfproto:No counterfactual found!
#                 There's been a problem while computing the explanation for observation: 3.
#                 If this observation is critical to you try with some other hyperparameters.
#
# 5 counterfactuals already computed. Found a solution for 4 of them
# All counterfactuals have been computed and regularized
# There were a total of 1 fails
# The 3 most important features and their importance values according to the first metric (amount features change) are:
#     petal length (cm) 1.00 -1.00 AND sepal length (cm) 0.45 -1.00 AND sepal width (cm) 0.11 1.00.
#
# According to the second metric (times features change), these importances are:
#     sepal length (cm) 1.00 AND petal length (cm) 1.00 AND sepal width (cm) 0.50

# %% [markdown]
# ## AnchorsExplainer
#
# Existe también una extensión del AnchorsExplainer en alibi con la capacidad de obtener las importancias de las features para el modelo.
#
# El método de anchors explica predicciones individuales de los modelos encontrando una regla (anchor) donde la predicción del modelo se mantiene aun cambiando los valores de las demás features.
#
# Vamos a ver un ejemplo. Para ello utilizamos el compoenente `AnchorsWithImportanceExplainer`:

# %%
from mercury.explainability import AnchorsWithImportanceExplainer

# %%
anchorsExplainer = AnchorsWithImportanceExplainer(
    predict_fn=rf.predict_proba,
    train_data=predictors
)

# %% [markdown]
# Vamos a explicar el primer sample de nuestro dataset:

# %%
anchor_explanation = anchorsExplainer.explain(predictors.head(1).values)

# %%
print("prediction: ", anchor_explanation.data['raw']['prediction'])
print("anchor: ", anchor_explanation.data['anchor'])  
print("precision: ", anchor_explanation.data['precision']) # fraction of times the sampled instances the anchor holds with the same prediction
print("coverage: ", anchor_explanation.data['coverage']) #the fraction of sampled instances the anchor applies to.
# Out:
# prediction:  0
# anchor:  ['petal width (cm) <= 0.30', 'petal length (cm) <= 1.60']
# precision:  1.0
# coverage:  0.29333333333333333

# %% [markdown]
# Observamos que el anchor encontrado es: cuando la feature "petal width" <= 0.30 y la feature "petal length" <= 1.60 nuestro modelo predice la clase 0 el 100%  (precision=1) de las veces que esto ocurre en nuestro dataset. Esto ha cubierto el 29.33% de los casos de la clase. Podemos utilizar el método `translate` para obtener directamente una explicación de manera intuitiva:

# %%
anchorsExplainer.translate(anchor_explanation)
# Out:
# '[GOOD explanation] This anchor explains a 29.33% of all records of its class with 100.0% confidence.'

# %% [markdown]
# Podemos utilizar el método `get_feature_importance` para obtener las features más importantes a la hora de explicar las predicciones en un set de datos:

# %%
explanation = anchorsExplainer.get_feature_importance(explain_data=predictors.head(20))

# %%
explanation.interpret_explanations(n_important_features=2);
# Out:
# The 2 most common features are: petal width (cm) <= with a frequency of 20 (100.0%) petal length (cm) <= with a frequency of 19 (95.0%)

# %% [markdown]
# ## ALE Explainer (+ ALE plots)
#
# Accumulated Local Effects (ALE) es un método para calcular los efectos de las features de manera global. El método tiene cierta similitud a los Partial Dependence Plots (PDP) e intenta corregir algunos problemas de este.
#
# Los Partial Dependence Plots pueden sufrir problemas cuando una feature tiene fuerte correlación con otras. Esto se debe a que para su cálculo se pueden generar instancias sintéticas que son muy difíciles (o imposibles) que ocurran. Esto puede sesgar el efecto estimado de las features. Los ALE plots intentan solucionar este problema midiendo los cambios en las predicciones en lugar de las predicciones en sí mismas. Además, los ALE plots son más rápidos de calcular que los PDP.
#
# Puede conocer más en detalle el método [aquí](https://christophm.github.io/interpretable-ml-book/ale.html)
#
# En mercury.explainability, podemos el método está implementado en la clase `ALEExplainer`:

# %%
from mercury.explainability import ALEExplainer

# %%
ale = ALEExplainer(rf.predict_proba, 
                   target_names=list(iris.target_names)  # Para que la explicacion incluya el nombre de las clases
)

# %%
exp = ale.explain(predictors)

# %% [markdown]
# Una vez ejecutado el explainer, importamos la función `plot_ale` para mostrar los ALE plots:

# %%
from mercury.explainability.explainers.ale import plot_ale

# %%
plot_ale(exp, n_cols=2, sharey=None, targets=[0,1,2])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4e571f2670>,
# ...
#       dtype=object)

# %% [markdown]
# Los ALE plots muestras el efecto de una feature cuando esta tiene cierto valor comparado con la predicción media. Podemos ver un ejemplo en la figura anterior. Para la feature "petal length" (esquina inferior izquierda) el tener un valor pequeño de la feature (menor de 2) provoca que la predicción media de pertenecer a la clase setosa aumente más de 0.2. En cambio, para valores de esta feature mayores 3.5 la predicción media de pertenecer a esta clase disminuye
